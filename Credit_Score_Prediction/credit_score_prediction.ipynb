# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.impute import SimpleImputer


from sklearn.metrics import (
    accuracy_score,
    f1_score,
    precision_score,
    recall_score,
    roc_auc_score,
    classification_report
)

# %%
credit_data = pd.read_csv('/content/loan_data_1248.csv')
credit_data.head()
# Out:
#          income   loan_amount  term  credit_history  defaulted
# 0  60940.854754  17402.715471    60             1.0          1
# 1  49511.242579   6664.626123    36             0.0          0
# 2  63658.393686  17985.281393    60             0.0          1
# 3  79414.537415  21001.173770    36             1.0          0
# 4  47785.239255   4037.586145    36             1.0          0

# %%
credit_data.shape
# Out:
# (1248, 5)

# %%
credit_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1248 entries, 0 to 1247
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   income          1128 non-null   float64
#  1   loan_amount     1126 non-null   float64
#  2   term            1248 non-null   int64
#  3   credit_history  1136 non-null   float64
#  4   defaulted       1248 non-null   int64
# dtypes: float64(3), int64(2)
# memory usage: 48.9 KB

# %%
print(credit_data.isnull().sum())
# Out:
# income            120
# loan_amount       122
# term                0
# credit_history    112
# defaulted           0
# dtype: int64

# %%
imputer = SimpleImputer(strategy='mean')
columns_to_impute = ['income', 'loan_amount', 'credit_history']
credit_data[columns_to_impute] = imputer.fit_transform(credit_data[columns_to_impute])
print("Missing values after imputation:")
print(credit_data.isnull().sum())
# Out:
# Missing values after imputation:
# income            0
# loan_amount       0
# term              0
# credit_history    0
# defaulted         0
# dtype: int64

# %%
X = credit_data.drop(columns='defaulted', axis=1)
Y = credit_data['defaulted']


imputer = SimpleImputer(strategy='mean')
X = imputer.fit_transform(X)

# %%
X = credit_data.drop(columns = 'defaulted',axis = 1)
Y = credit_data['defaulted']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 2)

# %%
model = LogisticRegression()
model.fit (X_train,Y_train)
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)
print('Accuracy on Training data : ', training_data_accuracy)
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)
print('Accuracy score on Test Data : ', test_data_accuracy)
# Out:
# Accuracy on Training data :  0.6773547094188377
# Accuracy score on Test Data :  0.636
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
precision = precision_score(Y_test, X_test_prediction)
print(precision)
# Out:
# 0.5802469135802469

# %%
recall = recall_score(Y_test, X_test_prediction)
print(recall)
# Out:
# 0.4519230769230769

# %%
f1_score = f1_score(Y_test,X_test_prediction)
print(f1_score)
# Out:
# 0.5081081081081081

# %%
X_prob = model.predict_proba(X_test)[:, 1]
roc_auc = roc_auc_score(Y_test, X_prob)
print(roc_auc)
# Out:
# 0.6406743940990517

# %%
classification_report = classification_report(Y_test, X_test_prediction)
print(classification_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.77      0.71       146
#            1       0.58      0.45      0.51       104
#
#     accuracy                           0.64       250
#    macro avg       0.62      0.61      0.61       250
# weighted avg       0.63      0.64      0.63       250

# %%
input_data_numpy_array = np.asarray(input_data)
input_data_reshaped = input_data_numpy_array.reshape(1, -1)

std_data = scaler.transform(input_data_reshaped)

prediction = model.predict(std_data)

print(prediction)
if prediction[0] == 0:
    print("The customer is not likely to default")
else:
    print("The customer is likely to default")
# Out:
# [1]
# The customer is likely to default
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
